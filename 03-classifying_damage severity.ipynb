# %%
# %%time
import boto3
import re
import numpy as np
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
# Out:
# CPU times: user 789 ms, sys: 52 ms, total: 841 ms
# Wall time: 844 ms

# %%
role = get_execution_role()
print(role)
bucket='zurich-aiml-projects'
training_image = get_image_uri(boto3.Session().region_name, 'image-classification')
print (training_image)
# Out:
# arn:aws:iam::811843694063:role/service-role/AmazonSageMaker-ExecutionRole-20190611T192276
# 811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:1

# %%
#the very first step after crreating a bucket is - provide read/write access to Amazon Sagemaker Execution role
#Step 1:Download the .jpeg data from s3 to local directory as we can not use im2rec tool on S3 data directly
# !aws s3 cp s3://zurich-aiml-projects/cardamagedetective/dataset/data3a ./dataset/data3a --recursive
# Out:
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/train_lst/trainingdata03.lst to dataset/data3a/train_lst/trainingdata03.lst
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0001.JPEG to dataset/data3a/training/01-minor/0001.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0005.JPEG to dataset/data3a/training/01-minor/0005.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0008.JPEG to dataset/data3a/training/01-minor/0008.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0002.JPEG to dataset/data3a/training/01-minor/0002.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0010.JPEG to dataset/data3a/training/01-minor/0010.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0011.JPEG to dataset/data3a/training/01-minor/0011.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0003.JPEG to dataset/data3a/training/01-minor/0003.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0009.JPEG to dataset/data3a/training/01-minor/0009.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0007.JPEG to dataset/data3a/training/01-minor/0007.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0017.JPEG to dataset/data3a/training/01-minor/0017.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0006.JPEG to dataset/data3a/training/01-minor/0006.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0004.JPEG to dataset/data3a/training/01-minor/0004.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0018.JPEG to dataset/data3a/training/01-minor/0018.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0021.JPEG to dataset/data3a/training/01-minor/0021.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0012.JPEG to dataset/data3a/training/01-minor/0012.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0020.JPEG to dataset/data3a/training/01-minor/0020.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0019.JPEG to dataset/data3a/training/01-minor/0019.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0022.JPEG to dataset/data3a/training/01-minor/0022.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0023.JPEG to dataset/data3a/training/01-minor/0023.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0025.JPEG to dataset/data3a/training/01-minor/0025.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0024.JPEG to dataset/data3a/training/01-minor/0024.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0033.JPEG to dataset/data3a/training/01-minor/0033.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0013.JPEG to dataset/data3a/training/01-minor/0013.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0032.JPEG to dataset/data3a/training/01-minor/0032.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0015.JPEG to dataset/data3a/training/01-minor/0015.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0035.jpeg to dataset/data3a/training/01-minor/0035.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0029.JPEG to dataset/data3a/training/01-minor/0029.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0028.JPEG to dataset/data3a/training/01-minor/0028.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0014.JPEG to dataset/data3a/training/01-minor/0014.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0016.JPEG to dataset/data3a/training/01-minor/0016.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0026.JPEG to dataset/data3a/training/01-minor/0026.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0031.JPEG to dataset/data3a/training/01-minor/0031.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0034.JPEG to dataset/data3a/training/01-minor/0034.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0036.JPEG to dataset/data3a/training/01-minor/0036.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0042.JPEG to dataset/data3a/training/01-minor/0042.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0040.JPEG to dataset/data3a/training/01-minor/0040.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0030.JPEG to dataset/data3a/training/01-minor/0030.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0027.JPEG to dataset/data3a/training/01-minor/0027.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0037.JPEG to dataset/data3a/training/01-minor/0037.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0041.JPEG to dataset/data3a/training/01-minor/0041.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0038.JPEG to dataset/data3a/training/01-minor/0038.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0043.JPEG to dataset/data3a/training/01-minor/0043.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0045.JPEG to dataset/data3a/training/01-minor/0045.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0050.JPEG to dataset/data3a/training/01-minor/0050.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0039.JPEG to dataset/data3a/training/01-minor/0039.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0046.JPEG to dataset/data3a/training/01-minor/0046.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0044.JPEG to dataset/data3a/training/01-minor/0044.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0048.JPEG to dataset/data3a/training/01-minor/0048.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0052.JPEG to dataset/data3a/training/01-minor/0052.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0049.JPEG to dataset/data3a/training/01-minor/0049.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0047.JPEG to dataset/data3a/training/01-minor/0047.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0051.JPEG to dataset/data3a/training/01-minor/0051.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0054.jpeg to dataset/data3a/training/01-minor/0054.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0058.JPEG to dataset/data3a/training/01-minor/0058.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0055.JPEG to dataset/data3a/training/01-minor/0055.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0057.JPEG to dataset/data3a/training/01-minor/0057.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0060.JPEG to dataset/data3a/training/01-minor/0060.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0053.JPEG to dataset/data3a/training/01-minor/0053.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0059.JPEG to dataset/data3a/training/01-minor/0059.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0056.JPEG to dataset/data3a/training/01-minor/0056.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0065.JPEG to dataset/data3a/training/01-minor/0065.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0062.JPEG to dataset/data3a/training/01-minor/0062.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0064.JPEG to dataset/data3a/training/01-minor/0064.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0066.JPEG to dataset/data3a/training/01-minor/0066.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0068.JPEG to dataset/data3a/training/01-minor/0068.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0072.JPEG to dataset/data3a/training/01-minor/0072.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0071.JPEG to dataset/data3a/training/01-minor/0071.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0063.JPEG to dataset/data3a/training/01-minor/0063.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0074.JPEG to dataset/data3a/training/01-minor/0074.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0070.JPEG to dataset/data3a/training/01-minor/0070.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0076.JPEG to dataset/data3a/training/01-minor/0076.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0073.JPEG to dataset/data3a/training/01-minor/0073.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0075.JPEG to dataset/data3a/training/01-minor/0075.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0061.jpeg to dataset/data3a/training/01-minor/0061.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0077.JPEG to dataset/data3a/training/01-minor/0077.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0067.JPEG to dataset/data3a/training/01-minor/0067.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0069.JPEG to dataset/data3a/training/01-minor/0069.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0083.JPEG to dataset/data3a/training/01-minor/0083.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0078.JPEG to dataset/data3a/training/01-minor/0078.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0079.JPEG to dataset/data3a/training/01-minor/0079.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0081.JPEG to dataset/data3a/training/01-minor/0081.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0086.JPEG to dataset/data3a/training/01-minor/0086.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0080.JPEG to dataset/data3a/training/01-minor/0080.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0087.JPEG to dataset/data3a/training/01-minor/0087.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0084.JPEG to dataset/data3a/training/01-minor/0084.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0089.JPEG to dataset/data3a/training/01-minor/0089.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0088.JPEG to dataset/data3a/training/01-minor/0088.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0082.JPEG to dataset/data3a/training/01-minor/0082.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0085.JPEG to dataset/data3a/training/01-minor/0085.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0094.JPEG to dataset/data3a/training/01-minor/0094.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0091.JPEG to dataset/data3a/training/01-minor/0091.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0092.JPEG to dataset/data3a/training/01-minor/0092.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0090.JPEG to dataset/data3a/training/01-minor/0090.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0095.JPEG to dataset/data3a/training/01-minor/0095.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0098.JPEG to dataset/data3a/training/01-minor/0098.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0093.JPEG to dataset/data3a/training/01-minor/0093.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0096.JPEG to dataset/data3a/training/01-minor/0096.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0097.JPEG to dataset/data3a/training/01-minor/0097.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0102.JPEG to dataset/data3a/training/01-minor/0102.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0099.JPEG to dataset/data3a/training/01-minor/0099.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0103.JPEG to dataset/data3a/training/01-minor/0103.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0100.JPEG to dataset/data3a/training/01-minor/0100.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0105.JPEG to dataset/data3a/training/01-minor/0105.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0109.JPEG to dataset/data3a/training/01-minor/0109.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0104.JPEG to dataset/data3a/training/01-minor/0104.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0110.JPEG to dataset/data3a/training/01-minor/0110.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0111.JPEG to dataset/data3a/training/01-minor/0111.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0106.JPEG to dataset/data3a/training/01-minor/0106.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0101.JPEG to dataset/data3a/training/01-minor/0101.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0113.JPEG to dataset/data3a/training/01-minor/0113.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0108.JPEG to dataset/data3a/training/01-minor/0108.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0107.JPEG to dataset/data3a/training/01-minor/0107.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0112.JPEG to dataset/data3a/training/01-minor/0112.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0114.JPEG to dataset/data3a/training/01-minor/0114.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0118.JPEG to dataset/data3a/training/01-minor/0118.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0119.JPEG to dataset/data3a/training/01-minor/0119.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0117.JPEG to dataset/data3a/training/01-minor/0117.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0123.JPEG to dataset/data3a/training/01-minor/0123.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0115.JPEG to dataset/data3a/training/01-minor/0115.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0120.JPEG to dataset/data3a/training/01-minor/0120.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0124.JPEG to dataset/data3a/training/01-minor/0124.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0125.JPEG to dataset/data3a/training/01-minor/0125.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0126.JPEG to dataset/data3a/training/01-minor/0126.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0134.jpeg to dataset/data3a/training/01-minor/0134.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0136.JPEG to dataset/data3a/training/01-minor/0136.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0127.JPEG to dataset/data3a/training/01-minor/0127.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0132.JPEG to dataset/data3a/training/01-minor/0132.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0116.JPEG to dataset/data3a/training/01-minor/0116.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0121.JPEG to dataset/data3a/training/01-minor/0121.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0128.JPEG to dataset/data3a/training/01-minor/0128.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0133.JPEG to dataset/data3a/training/01-minor/0133.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0135.JPEG to dataset/data3a/training/01-minor/0135.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0139.JPEG to dataset/data3a/training/01-minor/0139.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0137.JPEG to dataset/data3a/training/01-minor/0137.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0138.JPEG to dataset/data3a/training/01-minor/0138.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0141.JPEG to dataset/data3a/training/01-minor/0141.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0131.jpeg to dataset/data3a/training/01-minor/0131.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0144.JPEG to dataset/data3a/training/01-minor/0144.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0147.JPEG to dataset/data3a/training/01-minor/0147.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0122.JPEG to dataset/data3a/training/01-minor/0122.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0130.JPEG to dataset/data3a/training/01-minor/0130.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0140.JPEG to dataset/data3a/training/01-minor/0140.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0143.JPEG to dataset/data3a/training/01-minor/0143.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0142.JPEG to dataset/data3a/training/01-minor/0142.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0129.JPEG to dataset/data3a/training/01-minor/0129.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0149.JPEG to dataset/data3a/training/01-minor/0149.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0146.JPEG to dataset/data3a/training/01-minor/0146.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0145.JPEG to dataset/data3a/training/01-minor/0145.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0153.JPEG to dataset/data3a/training/01-minor/0153.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0160.JPEG to dataset/data3a/training/01-minor/0160.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0156.JPEG to dataset/data3a/training/01-minor/0156.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0155.JPEG to dataset/data3a/training/01-minor/0155.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0150.JPEG to dataset/data3a/training/01-minor/0150.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0151.JPEG to dataset/data3a/training/01-minor/0151.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0161.JPEG to dataset/data3a/training/01-minor/0161.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0157.JPEG to dataset/data3a/training/01-minor/0157.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0152.JPEG to dataset/data3a/training/01-minor/0152.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0168.JPEG to dataset/data3a/training/01-minor/0168.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0162.JPEG to dataset/data3a/training/01-minor/0162.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0165.JPEG to dataset/data3a/training/01-minor/0165.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0167.JPEG to dataset/data3a/training/01-minor/0167.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0164.JPEG to dataset/data3a/training/01-minor/0164.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0163.JPEG to dataset/data3a/training/01-minor/0163.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0154.JPEG to dataset/data3a/training/01-minor/0154.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0158.JPEG to dataset/data3a/training/01-minor/0158.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0171.JPEG to dataset/data3a/training/01-minor/0171.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0169.JPEG to dataset/data3a/training/01-minor/0169.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0172.JPEG to dataset/data3a/training/01-minor/0172.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0170.JPEG to dataset/data3a/training/01-minor/0170.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0174.JPEG to dataset/data3a/training/01-minor/0174.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0175.JPEG to dataset/data3a/training/01-minor/0175.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0176.JPEG to dataset/data3a/training/01-minor/0176.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0177.JPEG to dataset/data3a/training/01-minor/0177.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0173.JPEG to dataset/data3a/training/01-minor/0173.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0179.JPEG to dataset/data3a/training/01-minor/0179.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0178.JPEG to dataset/data3a/training/01-minor/0178.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0180.JPEG to dataset/data3a/training/01-minor/0180.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0181.JPEG to dataset/data3a/training/01-minor/0181.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0183.JPEG to dataset/data3a/training/01-minor/0183.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0182.JPEG to dataset/data3a/training/01-minor/0182.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0186.JPEG to dataset/data3a/training/01-minor/0186.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0188.JPEG to dataset/data3a/training/01-minor/0188.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0187.JPEG to dataset/data3a/training/01-minor/0187.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0148.JPEG to dataset/data3a/training/01-minor/0148.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0189.JPEG to dataset/data3a/training/01-minor/0189.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0166.JPEG to dataset/data3a/training/01-minor/0166.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0193.JPEG to dataset/data3a/training/01-minor/0193.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0185.JPEG to dataset/data3a/training/01-minor/0185.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0184.JPEG to dataset/data3a/training/01-minor/0184.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0195.JPEG to dataset/data3a/training/01-minor/0195.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0194.JPEG to dataset/data3a/training/01-minor/0194.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0197.JPEG to dataset/data3a/training/01-minor/0197.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0190.JPEG to dataset/data3a/training/01-minor/0190.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0159.JPEG to dataset/data3a/training/01-minor/0159.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0196.JPEG to dataset/data3a/training/01-minor/0196.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0198.JPEG to dataset/data3a/training/01-minor/0198.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0200.JPEG to dataset/data3a/training/01-minor/0200.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0204.JPEG to dataset/data3a/training/01-minor/0204.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0206.JPEG to dataset/data3a/training/01-minor/0206.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0191.JPEG to dataset/data3a/training/01-minor/0191.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0205.JPEG to dataset/data3a/training/01-minor/0205.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0201.JPEG to dataset/data3a/training/01-minor/0201.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0202.JPEG to dataset/data3a/training/01-minor/0202.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0210.JPEG to dataset/data3a/training/01-minor/0210.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0203.JPEG to dataset/data3a/training/01-minor/0203.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0212.JPEG to dataset/data3a/training/01-minor/0212.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0209.JPEG to dataset/data3a/training/01-minor/0209.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0211.jpeg to dataset/data3a/training/01-minor/0211.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0214.JPEG to dataset/data3a/training/01-minor/0214.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0192.JPEG to dataset/data3a/training/01-minor/0192.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0215.jpeg to dataset/data3a/training/01-minor/0215.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0217.JPEG to dataset/data3a/training/01-minor/0217.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0216.JPEG to dataset/data3a/training/01-minor/0216.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0213.jpeg to dataset/data3a/training/01-minor/0213.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0218.JPEG to dataset/data3a/training/01-minor/0218.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0219.JPEG to dataset/data3a/training/01-minor/0219.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0222.JPEG to dataset/data3a/training/01-minor/0222.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0220.JPEG to dataset/data3a/training/01-minor/0220.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0221.JPEG to dataset/data3a/training/01-minor/0221.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0207.JPEG to dataset/data3a/training/01-minor/0207.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0226.JPEG to dataset/data3a/training/01-minor/0226.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0199.JPEG to dataset/data3a/training/01-minor/0199.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0224.JPEG to dataset/data3a/training/01-minor/0224.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0225.JPEG to dataset/data3a/training/01-minor/0225.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0227.JPEG to dataset/data3a/training/01-minor/0227.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0229.JPEG to dataset/data3a/training/01-minor/0229.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0230.JPEG to dataset/data3a/training/01-minor/0230.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0231.JPEG to dataset/data3a/training/01-minor/0231.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0228.JPEG to dataset/data3a/training/01-minor/0228.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0236.JPEG to dataset/data3a/training/01-minor/0236.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0233.JPEG to dataset/data3a/training/01-minor/0233.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0238.JPEG to dataset/data3a/training/01-minor/0238.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0235.JPEG to dataset/data3a/training/01-minor/0235.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0241.JPEG to dataset/data3a/training/01-minor/0241.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0240.JPEG to dataset/data3a/training/01-minor/0240.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0232.JPEG to dataset/data3a/training/01-minor/0232.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0239.JPEG to dataset/data3a/training/01-minor/0239.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0246.JPEG to dataset/data3a/training/01-minor/0246.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0237.JPEG to dataset/data3a/training/01-minor/0237.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0243.JPEG to dataset/data3a/training/01-minor/0243.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0208.JPEG to dataset/data3a/training/01-minor/0208.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0245.jpeg to dataset/data3a/training/01-minor/0245.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0248.JPEG to dataset/data3a/training/01-minor/0248.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0242.JPEG to dataset/data3a/training/01-minor/0242.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0249.JPEG to dataset/data3a/training/01-minor/0249.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0250.JPEG to dataset/data3a/training/01-minor/0250.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0253.jpeg to dataset/data3a/training/01-minor/0253.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0252.JPEG to dataset/data3a/training/01-minor/0252.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0254.JPEG to dataset/data3a/training/01-minor/0254.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0223.JPEG to dataset/data3a/training/01-minor/0223.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0234.JPEG to dataset/data3a/training/01-minor/0234.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0244.JPEG to dataset/data3a/training/01-minor/0244.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0259.JPEG to dataset/data3a/training/01-minor/0259.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0251.JPEG to dataset/data3a/training/01-minor/0251.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0262.JPEG to dataset/data3a/training/01-minor/0262.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0264.JPEG to dataset/data3a/training/01-minor/0264.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0263.JPEG to dataset/data3a/training/01-minor/0263.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0261.JPEG to dataset/data3a/training/01-minor/0261.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0257.JPEG to dataset/data3a/training/01-minor/0257.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0255.JPEG to dataset/data3a/training/01-minor/0255.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0260.JPEG to dataset/data3a/training/01-minor/0260.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0266.JPEG to dataset/data3a/training/01-minor/0266.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0265.JPEG to dataset/data3a/training/01-minor/0265.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0268.JPEG to dataset/data3a/training/01-minor/0268.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0270.jpeg to dataset/data3a/training/01-minor/0270.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0272.JPEG to dataset/data3a/training/01-minor/0272.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0274.JPEG to dataset/data3a/training/01-minor/0274.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0269.JPEG to dataset/data3a/training/01-minor/0269.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0267.JPEG to dataset/data3a/training/01-minor/0267.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0276.JPEG to dataset/data3a/training/01-minor/0276.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0273.JPEG to dataset/data3a/training/01-minor/0273.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0278.jpeg to dataset/data3a/training/01-minor/0278.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0003.JPEG to dataset/data3a/training/02-moderate/0003.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0277.JPEG to dataset/data3a/training/01-minor/0277.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0002.JPEG to dataset/data3a/training/02-moderate/0002.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0275.JPEG to dataset/data3a/training/01-minor/0275.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0004.JPEG to dataset/data3a/training/02-moderate/0004.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0007.JPEG to dataset/data3a/training/02-moderate/0007.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0006.JPEG to dataset/data3a/training/02-moderate/0006.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0008.JPEG to dataset/data3a/training/02-moderate/0008.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0010.JPEG to dataset/data3a/training/02-moderate/0010.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0011.JPEG to dataset/data3a/training/02-moderate/0011.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0005.JPEG to dataset/data3a/training/02-moderate/0005.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0009.JPEG to dataset/data3a/training/02-moderate/0009.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0271.JPEG to dataset/data3a/training/01-minor/0271.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0013.JPEG to dataset/data3a/training/02-moderate/0013.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0256.JPEG to dataset/data3a/training/01-minor/0256.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0247.JPEG to dataset/data3a/training/01-minor/0247.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0001.JPEG to dataset/data3a/training/02-moderate/0001.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0016.JPEG to dataset/data3a/training/02-moderate/0016.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0018.JPEG to dataset/data3a/training/02-moderate/0018.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0017.JPEG to dataset/data3a/training/02-moderate/0017.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0015.JPEG to dataset/data3a/training/02-moderate/0015.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0014.JPEG to dataset/data3a/training/02-moderate/0014.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0021.JPEG to dataset/data3a/training/02-moderate/0021.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0022.JPEG to dataset/data3a/training/02-moderate/0022.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0019.JPEG to dataset/data3a/training/02-moderate/0019.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0020.JPEG to dataset/data3a/training/02-moderate/0020.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0026.JPEG to dataset/data3a/training/02-moderate/0026.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0030.JPEG to dataset/data3a/training/02-moderate/0030.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0027.JPEG to dataset/data3a/training/02-moderate/0027.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0029.JPEG to dataset/data3a/training/02-moderate/0029.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0028.JPEG to dataset/data3a/training/02-moderate/0028.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0031.JPEG to dataset/data3a/training/02-moderate/0031.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0032.JPEG to dataset/data3a/training/02-moderate/0032.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0025.JPEG to dataset/data3a/training/02-moderate/0025.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0024.JPEG to dataset/data3a/training/02-moderate/0024.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0037.JPEG to dataset/data3a/training/02-moderate/0037.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0034.JPEG to dataset/data3a/training/02-moderate/0034.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0035.JPEG to dataset/data3a/training/02-moderate/0035.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0012.JPEG to dataset/data3a/training/02-moderate/0012.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0040.JPEG to dataset/data3a/training/02-moderate/0040.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0033.JPEG to dataset/data3a/training/02-moderate/0033.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0038.JPEG to dataset/data3a/training/02-moderate/0038.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0043.JPEG to dataset/data3a/training/02-moderate/0043.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0042.JPEG to dataset/data3a/training/02-moderate/0042.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0039.JPEG to dataset/data3a/training/02-moderate/0039.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0046.JPEG to dataset/data3a/training/02-moderate/0046.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0049.JPEG to dataset/data3a/training/02-moderate/0049.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0048.JPEG to dataset/data3a/training/02-moderate/0048.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0050.JPEG to dataset/data3a/training/02-moderate/0050.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0036.JPEG to dataset/data3a/training/02-moderate/0036.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0045.JPEG to dataset/data3a/training/02-moderate/0045.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0047.JPEG to dataset/data3a/training/02-moderate/0047.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0053.JPEG to dataset/data3a/training/02-moderate/0053.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0051.JPEG to dataset/data3a/training/02-moderate/0051.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0055.JPEG to dataset/data3a/training/02-moderate/0055.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0023.JPEG to dataset/data3a/training/02-moderate/0023.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0052.JPEG to dataset/data3a/training/02-moderate/0052.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0054.JPEG to dataset/data3a/training/02-moderate/0054.JPEG
# ...
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0013.JPEG to dataset/data3a/validation/02-moderate/0013.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0023.JPEG to dataset/data3a/validation/02-moderate/0023.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0025.JPEG to dataset/data3a/validation/02-moderate/0025.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0024.jpeg to dataset/data3a/validation/02-moderate/0024.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0027.JPEG to dataset/data3a/validation/02-moderate/0027.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0020.JPEG to dataset/data3a/validation/02-moderate/0020.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0026.JPEG to dataset/data3a/validation/02-moderate/0026.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0029.JPEG to dataset/data3a/validation/02-moderate/0029.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0036.JPEG to dataset/data3a/validation/02-moderate/0036.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0035.JPEG to dataset/data3a/validation/02-moderate/0035.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0032.JPEG to dataset/data3a/validation/02-moderate/0032.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0033.JPEG to dataset/data3a/validation/02-moderate/0033.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0031.JPEG to dataset/data3a/validation/02-moderate/0031.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0039.JPEG to dataset/data3a/validation/02-moderate/0039.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0002.JPEG to dataset/data3a/validation/02-moderate/0002.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0030.JPEG to dataset/data3a/validation/02-moderate/0030.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0034.JPEG to dataset/data3a/validation/02-moderate/0034.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0040.JPEG to dataset/data3a/validation/02-moderate/0040.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0001.JPEG to dataset/data3a/validation/02-moderate/0001.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0041.JPEG to dataset/data3a/validation/02-moderate/0041.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0038.JPEG to dataset/data3a/validation/02-moderate/0038.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0042.JPEG to dataset/data3a/validation/02-moderate/0042.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0047.JPEG to dataset/data3a/validation/02-moderate/0047.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0044.JPEG to dataset/data3a/validation/02-moderate/0044.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0037.JPEG to dataset/data3a/validation/02-moderate/0037.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0051.JPEG to dataset/data3a/validation/02-moderate/0051.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0043.JPEG to dataset/data3a/validation/02-moderate/0043.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0052.JPEG to dataset/data3a/validation/02-moderate/0052.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0054.JPEG to dataset/data3a/validation/02-moderate/0054.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0050.JPEG to dataset/data3a/validation/02-moderate/0050.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0053.JPEG to dataset/data3a/validation/02-moderate/0053.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0048.JPEG to dataset/data3a/validation/02-moderate/0048.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0046.JPEG to dataset/data3a/validation/02-moderate/0046.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0007.JPEG to dataset/data3a/validation/03-severe/0007.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0002.JPEG to dataset/data3a/validation/03-severe/0002.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0006.JPEG to dataset/data3a/validation/03-severe/0006.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0009.JPEG to dataset/data3a/validation/03-severe/0009.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0049.JPEG to dataset/data3a/validation/02-moderate/0049.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0012.JPEG to dataset/data3a/validation/03-severe/0012.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0010.jpeg to dataset/data3a/validation/03-severe/0010.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0011.JPEG to dataset/data3a/validation/03-severe/0011.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0005.JPEG to dataset/data3a/validation/03-severe/0005.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0016.JPEG to dataset/data3a/validation/03-severe/0016.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0045.JPEG to dataset/data3a/validation/02-moderate/0045.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0017.JPEG to dataset/data3a/validation/03-severe/0017.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0014.JPEG to dataset/data3a/validation/03-severe/0014.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0001.JPEG to dataset/data3a/validation/03-severe/0001.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0015.JPEG to dataset/data3a/validation/03-severe/0015.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0019.JPEG to dataset/data3a/validation/03-severe/0019.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0023.JPEG to dataset/data3a/validation/03-severe/0023.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0020.JPEG to dataset/data3a/validation/03-severe/0020.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0022.JPEG to dataset/data3a/validation/03-severe/0022.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0018.JPEG to dataset/data3a/validation/03-severe/0018.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0013.JPEG to dataset/data3a/validation/03-severe/0013.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0021.JPEG to dataset/data3a/validation/03-severe/0021.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0026.JPEG to dataset/data3a/validation/03-severe/0026.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0025.JPEG to dataset/data3a/validation/03-severe/0025.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0027.JPEG to dataset/data3a/validation/03-severe/0027.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0028.JPEG to dataset/data3a/validation/03-severe/0028.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0024.JPEG to dataset/data3a/validation/03-severe/0024.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0033.JPEG to dataset/data3a/validation/03-severe/0033.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0032.JPEG to dataset/data3a/validation/03-severe/0032.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0031.JPEG to dataset/data3a/validation/03-severe/0031.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0029.JPEG to dataset/data3a/validation/03-severe/0029.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0004.JPEG to dataset/data3a/validation/03-severe/0004.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0034.JPEG to dataset/data3a/validation/03-severe/0034.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0036.jpeg to dataset/data3a/validation/03-severe/0036.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0008.JPEG to dataset/data3a/validation/03-severe/0008.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0035.JPEG to dataset/data3a/validation/03-severe/0035.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0037.jpeg to dataset/data3a/validation/03-severe/0037.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0040.JPEG to dataset/data3a/validation/03-severe/0040.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0030.JPEG to dataset/data3a/validation/03-severe/0030.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0043.JPEG to dataset/data3a/validation/03-severe/0043.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0044.JPEG to dataset/data3a/validation/03-severe/0044.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0041.JPEG to dataset/data3a/validation/03-severe/0041.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0042.JPEG to dataset/data3a/validation/03-severe/0042.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/02-moderate/0055.JPEG to dataset/data3a/validation/02-moderate/0055.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0048.jpeg to dataset/data3a/validation/03-severe/0048.jpeg
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0052.JPEG to dataset/data3a/validation/03-severe/0052.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0050.JPEG to dataset/data3a/validation/03-severe/0050.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0049.JPEG to dataset/data3a/validation/03-severe/0049.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0051.JPEG to dataset/data3a/validation/03-severe/0051.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0053.JPEG to dataset/data3a/validation/03-severe/0053.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0054.JPEG to dataset/data3a/validation/03-severe/0054.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0045.JPEG to dataset/data3a/validation/03-severe/0045.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0039.JPEG to dataset/data3a/validation/03-severe/0039.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0055.JPEG to dataset/data3a/validation/03-severe/0055.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0057.JPEG to dataset/data3a/validation/03-severe/0057.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0060.JPEG to dataset/data3a/validation/03-severe/0060.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0038.JPEG to dataset/data3a/validation/03-severe/0038.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0047.JPEG to dataset/data3a/validation/03-severe/0047.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0063.JPEG to dataset/data3a/validation/03-severe/0063.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0062.JPEG to dataset/data3a/validation/03-severe/0062.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0064.JPEG to dataset/data3a/validation/03-severe/0064.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0066.JPEG to dataset/data3a/validation/03-severe/0066.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0058.JPEG to dataset/data3a/validation/03-severe/0058.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0059.JPEG to dataset/data3a/validation/03-severe/0059.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0046.JPEG to dataset/data3a/validation/03-severe/0046.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0068.JPEG to dataset/data3a/validation/03-severe/0068.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0056.JPEG to dataset/data3a/validation/03-severe/0056.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0061.JPEG to dataset/data3a/validation/03-severe/0061.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0065.JPEG to dataset/data3a/validation/03-severe/0065.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0067.JPEG to dataset/data3a/validation/03-severe/0067.JPEG
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation_lst/validationdata03.lst to dataset/data3a/validation_lst/validationdata03.lst
# download: s3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/03-severe/0003.JPEG to dataset/data3a/validation/03-severe/0003.JPEG

# %%
#Look at this Image-classification-fulltraining-TestedCode.ipynb notebook for guidance
#Step 2: Download the im2rec.py tool
import os
import urllib.request

def download(url):
    filename = url.split("/")[-1]
    if not os.path.exists(filename):
        urllib.request.urlretrieve(url, filename)
        
# Tool for creating lst file
download('https://raw.githubusercontent.com/apache/incubator-mxnet/master/tools/im2rec.py')

# %%
# %%bash
# #Step 3: Create .lst files for training and validation data
# #.lst fils are prepared and stored on sagemaker instance
# python im2rec.py --list --recursive ./dataset/data3a/trainingdata03 ./dataset/data3a/training/
# python im2rec.py --list --recursive ./dataset/data3a/validationdata03 ./dataset/data3a/validation/
# #train-ratio is not specified as the entire data is traning set
# #https://arthurcaillau.com/image-record-iter/
# Out:
# 01-minor 0
# 02-moderate 1
# 03-severe 2
# 01-minor 0
# 02-moderate 1
# 03-severe 2

# %%
#Verify the data from .lst files to make sure they are created properly; Number of records should be equal to the number of images in 
#respective training and validation folders
# !head -n 100 ./dataset/data3a/validationdata03.lst > example.lst
f = open('example.lst','r')
lst_content = f.read()
print(lst_content)
# Out:
# 166	2.000000	03-severe/0064.JPEG
# 159	2.000000	03-severe/0057.JPEG
# 81	1.000000	02-moderate/0034.JPEG
# 57	1.000000	02-moderate/0010.JPEG
# 0	0.000000	01-minor/0001.JPEG
# 11	0.000000	01-minor/0012.JPEG
# 50	1.000000	02-moderate/0003.JPEG
# 144	2.000000	03-severe/0042.JPEG
# 120	2.000000	03-severe/0018.JPEG
# 23	0.000000	01-minor/0024.JPEG
# 62	1.000000	02-moderate/0015.jpeg
# 93	1.000000	02-moderate/0046.JPEG
# 148	2.000000	03-severe/0046.JPEG
# 154	2.000000	03-severe/0052.JPEG
# 29	0.000000	01-minor/0030.JPEG
# 169	2.000000	03-severe/0067.JPEG
# 165	2.000000	03-severe/0063.JPEG
# 47	0.000000	01-minor/0048.JPEG
# 128	2.000000	03-severe/0026.JPEG
# 113	2.000000	03-severe/0011.JPEG
# 19	0.000000	01-minor/0020.JPEG
# 54	1.000000	02-moderate/0007.JPEG
# 33	0.000000	01-minor/0034.JPEG
# 158	2.000000	03-severe/0056.JPEG
# 22	0.000000	01-minor/0023.JPEG
# 40	0.000000	01-minor/0041.JPEG
# 68	1.000000	02-moderate/0021.JPEG
# 151	2.000000	03-severe/0049.JPEG
# 149	2.000000	03-severe/0047.JPEG
# 17	0.000000	01-minor/0018.JPEG
# 107	2.000000	03-severe/0005.JPEG
# 124	2.000000	03-severe/0022.JPEG
# 4	0.000000	01-minor/0005.JPEG
# 126	2.000000	03-severe/0024.JPEG
# 109	2.000000	03-severe/0007.JPEG
# 146	2.000000	03-severe/0044.JPEG
# 13	0.000000	01-minor/0014.JPEG
# 8	0.000000	01-minor/0009.jpeg
# 132	2.000000	03-severe/0030.JPEG
# 112	2.000000	03-severe/0010.jpeg
# 105	2.000000	03-severe/0003.JPEG
# 92	1.000000	02-moderate/0045.JPEG
# 135	2.000000	03-severe/0033.JPEG
# 56	1.000000	02-moderate/0009.JPEG
# 145	2.000000	03-severe/0043.JPEG
# 3	0.000000	01-minor/0004.JPEG
# 10	0.000000	01-minor/0011.jpeg
# 121	2.000000	03-severe/0019.JPEG
# 167	2.000000	03-severe/0065.JPEG
# 2	0.000000	01-minor/0003.JPEG
# 34	0.000000	01-minor/0035.JPEG
# 123	2.000000	03-severe/0021.JPEG
# 84	1.000000	02-moderate/0037.JPEG
# 71	1.000000	02-moderate/0024.jpeg
# 78	1.000000	02-moderate/0031.JPEG
# 9	0.000000	01-minor/0010.JPEG
# 73	1.000000	02-moderate/0026.JPEG
# 108	2.000000	03-severe/0006.JPEG
# 25	0.000000	01-minor/0026.JPEG
# 142	2.000000	03-severe/0040.JPEG
# 59	1.000000	02-moderate/0012.jpeg
# 106	2.000000	03-severe/0004.JPEG
# 66	1.000000	02-moderate/0019.JPEG
# 5	0.000000	01-minor/0006.JPEG
# 26	0.000000	01-minor/0027.jpeg
# 80	1.000000	02-moderate/0033.JPEG
# 24	0.000000	01-minor/0025.JPEG
# 163	2.000000	03-severe/0061.JPEG
# 14	0.000000	01-minor/0015.JPEG
# 161	2.000000	03-severe/0059.JPEG
# 153	2.000000	03-severe/0051.JPEG
# 131	2.000000	03-severe/0029.JPEG
# 150	2.000000	03-severe/0048.jpeg
# 72	1.000000	02-moderate/0025.JPEG
# 27	0.000000	01-minor/0028.JPEG
# 164	2.000000	03-severe/0062.JPEG
# 39	0.000000	01-minor/0040.JPEG
# 162	2.000000	03-severe/0060.JPEG
# 76	1.000000	02-moderate/0029.JPEG
# 82	1.000000	02-moderate/0035.JPEG
# 15	0.000000	01-minor/0016.JPEG
# 35	0.000000	01-minor/0036.JPEG
# 122	2.000000	03-severe/0020.JPEG
# 21	0.000000	01-minor/0022.JPEG
# 133	2.000000	03-severe/0031.JPEG
# 95	1.000000	02-moderate/0048.JPEG
# 86	1.000000	02-moderate/0039.JPEG
# 102	1.000000	02-moderate/0055.JPEG
# 18	0.000000	01-minor/0019.JPEG
# 143	2.000000	03-severe/0041.JPEG
# 74	1.000000	02-moderate/0027.JPEG
# 63	1.000000	02-moderate/0016.JPEG
# 65	1.000000	02-moderate/0018.JPEG
# 98	1.000000	02-moderate/0051.JPEG
# 115	2.000000	03-severe/0013.JPEG
# 90	1.000000	02-moderate/0043.JPEG
# 30	0.000000	01-minor/0031.JPEG
# 32	0.000000	01-minor/0033.JPEG
# 55	1.000000	02-moderate/0008.JPEG
# 83	1.000000	02-moderate/0036.JPEG

# %%
#Copy the .lst files data to S3 train_lst and validation_lst channels
s3train03 = 's3://{}/cardamagedetective/dataset/data3a/training/'.format(bucket)
s3train03_lst = 's3://{}/cardamagedetective/dataset/data3a/train_lst/'.format(bucket)
s3validation03 = 's3://{}/cardamagedetective/dataset/data3a/validation/'.format(bucket)
s3validation03_lst = 's3://{}/cardamagedetective/dataset/data3a/validation_lst/'.format(bucket)

# !aws s3 cp ./dataset/data3a/trainingdata03.lst $s3train03_lst --quiet
# !aws s3 cp ./dataset/data3a/validationdata03.lst $s3validation03_lst --quiet
print('Done')
# Out:
# Done

# %%
#Training the ResNet model
#Set the hyperparameters (https://docs.aws.amazon.com/sagemaker/latest/dg/IC-Hyperparameter.html)
#This algorithm takes 'images' as input, instead of 'recordIO' file; .lst file is used along with the image files
# The algorithm supports multiple network depth (number of layers). They are 18, 34, 50, 101, 152 and 200
# For this training, we will use 18 layers
num_layers = "18" 
# we need to specify the input image shape for the training data
image_shape = "3,256,256"  
#for image_shape, when I give 2, the training job failed with error: Transfer learning only supports color images (3-channel) as input.
#The format is defined as 'num_channels, height, width'. The image dimension can take on any value as the network can handle varied dimensions of the input. 
#However, there may be memory constraints if a larger image dimension is used. 
#Typical image dimensions for image classification are '3, 224, 224'. This is similar to the ImageNet dataset.
# we also need to specify the number of training samples in the training set
# we have  419+288+272 = 979
num_training_samples = "979"
# specify the number of output classes
num_classes = 3 #is car damage location 'minor', or 'moderate' or 'severe'
# batch size for training
mini_batch_size =  "128"
# number of epochs
epochs = "10"
# learning rate
learning_rate = "0.01"
#report top 5 accuracy
top_k = "5"
#resize image before training
resize = "256"
#period to store modle parameters (in number of epochs), in this case, we will save parameters from epoch 2,4,and 6
checkpoint_frequency = 2
#since we are using transfer leanring, we set use_pretrained_model to 1, so that weights can be initialized with pretrained weights
use_pretrained_model = 1

# %%
# %%time
#Model training: Run the training using Amazon sagemaker CreateTrainingJob API
import time
import boto3
from time import gmtime, strftime


s3 = boto3.client('s3')
# create unique job name 
job_name_prefix = 'cardamagedetective-damage-severity'
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
job_name = job_name_prefix + timestamp
training_params = \
{
    # specify the training docker image
    "AlgorithmSpecification": {
        "TrainingImage": training_image,
        "TrainingInputMode": "File"
    },
    "RoleArn": role,
    "OutputDataConfig": {
        "S3OutputPath": 's3://{}/cardamagedetective/modeloutput'.format(bucket)
    },
    "ResourceConfig": {
        "InstanceCount": 1,
        "InstanceType": "ml.p2.xlarge",
        "VolumeSizeInGB": 50
    },
    "TrainingJobName": job_name,
    "HyperParameters": {
        "image_shape": image_shape,
        "num_layers": str(num_layers),
        "num_training_samples": str(num_training_samples),
        "num_classes": str(num_classes),
        "mini_batch_size": str(mini_batch_size),
        "epochs": str(epochs),
        "learning_rate": str(learning_rate),
        "top_k": str(top_k),
        "resize": str(resize),
        "checkpoint_frequency": str(checkpoint_frequency),
        "use_pretrained_model": str(use_pretrained_model)
    },
    "StoppingCondition": {
        "MaxRuntimeInSeconds": 360000
    },
#Need to provide S3 path for 4 channels - training, validation, train_lst and valdiation_lst
#Set the location by setting S3Uri variable. 
#Training data should be inside a subdirectory called "train"
#Validation data should be inside a subdirectory called "validation"
#The algorithm currently only supports fullyreplicated model (where data is copied onto each machine)
    "InputDataConfig": [
        {
            "ChannelName": "train",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3train03,
                    "S3DataDistributionType": "FullyReplicated"
                }
            },
            "ContentType": "application/x-image", #use x-image as we are using actual image data, instead of recordIO format
            "RecordWrapperType": "None",
            "CompressionType": "None"
        },
        {
            "ChannelName": "validation",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation03,
                    "S3DataDistributionType": "FullyReplicated"
                }
            },
            "ContentType": "application/x-image",   #use x-image as we are using actual image data, instead of recordIO format
            "RecordWrapperType": "None",
            "CompressionType": "None"
        },
        {
            "ChannelName": "train_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3train03_lst,
                    "S3DataDistributionType": "FullyReplicated"
                }
            },
            "ContentType": "application/x-image",   #use x-image as we are using actual image data, instead of recordIO format
            "RecordWrapperType": "None",
            "CompressionType": "None"
        },
        {
            "ChannelName": "validation_lst",
            "DataSource": {
                "S3DataSource": {
                    "S3DataType": "S3Prefix",
                    "S3Uri": s3validation03_lst,
                    "S3DataDistributionType": "FullyReplicated"
                }
            },
            "ContentType": "application/x-image",   #use x-image as we are using actual image data, instead of recordIO format
            "RecordWrapperType": "None",
            "CompressionType": "None"
        }
    ]
}
print('Training job name: {}'.format(job_name))
print('\nInput Data Location: {}'.format(training_params['InputDataConfig'][0]['DataSource']['S3DataSource']))
# Out:
# Training job name: cardamagedetective-damage-severity-2019-06-21-10-59-27
#
# Input Data Location: {'S3DataType': 'S3Prefix', 'S3Uri': 's3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/', 'S3DataDistributionType': 'FullyReplicated'}
# CPU times: user 40.5 ms, sys: 12.6 ms, total: 53.1 ms
# Wall time: 63.2 ms

# %%
# create the Amazon SageMaker training job
sagemaker = boto3.client(service_name='sagemaker')
sagemaker.create_training_job(**training_params)

# confirm that the training job has started
status = sagemaker.describe_training_job(TrainingJobName=job_name)['TrainingJobStatus']
print('Training job current status: {}'.format(status))

try:
    # waits for the job to finish and report the ending status (success/fail)
    sagemaker.get_waiter('training_job_completed_or_stopped').wait(TrainingJobName=job_name)
    training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
    status = training_info['TrainingJobStatus']
    print("Training job ended with status: " + status)
except:
    print('Training failed to start')
     # if exception is raised, that means it has failed
    message = sagemaker.describe_training_job(TrainingJobName=job_name)['FailureReason']
    print('Training failed with the following error: {}'.format(message))
# At the end of training job, you will find the model file created in S3 under output folder:s3://../modeloutput/cardamagedetective-car-or-not-2019-06-21-04-32-18/output/model.tar.gz
# Out:
# Training job current status: InProgress
# Training job ended with status: Completed

# %%
training_info = sagemaker.describe_training_job(TrainingJobName=job_name)
status = training_info['TrainingJobStatus']
print("Training job ended with status: " + status)
print(training_info)
# Out:
# Training job ended with status: Completed
# {'TrainingJobName': 'cardamagedetective-damage-severity-2019-06-21-10-59-27', 'TrainingJobArn': 'arn:aws:sagemaker:us-east-1:811843694063:training-job/cardamagedetective-damage-severity-2019-06-21-10-59-27', 'ModelArtifacts': {'S3ModelArtifacts': 's3://zurich-aiml-projects/cardamagedetective/modeloutput/cardamagedetective-damage-severity-2019-06-21-10-59-27/output/model.tar.gz'}, 'TrainingJobStatus': 'Completed', 'SecondaryStatus': 'Completed', 'HyperParameters': {'checkpoint_frequency': '2', 'epochs': '10', 'image_shape': '3,256,256', 'learning_rate': '0.01', 'mini_batch_size': '128', 'num_classes': '3', 'num_layers': '18', 'num_training_samples': '979', 'resize': '256', 'top_k': '5', 'use_pretrained_model': '1'}, 'AlgorithmSpecification': {'TrainingImage': '811284229777.dkr.ecr.us-east-1.amazonaws.com/image-classification:1', 'TrainingInputMode': 'File', 'MetricDefinitions': [{'Name': 'train:accuracy', 'Regex': 'Epoch\\S* Train-accuracy=(\\S*)'}, {'Name': 'validation:accuracy', 'Regex': 'Epoch\\S* Validation-accuracy=(\\S*)'}, {'Name': 'train:accuracy:epoch', 'Regex': 'Epoch\\S* Train-accuracy=(\\S*)'}, {'Name': 'validation:accuracy:epoch', 'Regex': 'Epoch\\S* Validation-accuracy=(\\S*)'}]}, 'RoleArn': 'arn:aws:iam::811843694063:role/service-role/AmazonSageMaker-ExecutionRole-20190611T192276', 'InputDataConfig': [{'ChannelName': 'train', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://zurich-aiml-projects/cardamagedetective/dataset/data3a/training/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'train_lst', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://zurich-aiml-projects/cardamagedetective/dataset/data3a/train_lst/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}, {'ChannelName': 'validation_lst', 'DataSource': {'S3DataSource': {'S3DataType': 'S3Prefix', 'S3Uri': 's3://zurich-aiml-projects/cardamagedetective/dataset/data3a/validation_lst/', 'S3DataDistributionType': 'FullyReplicated'}}, 'ContentType': 'application/x-image', 'CompressionType': 'None', 'RecordWrapperType': 'None'}], 'OutputDataConfig': {'KmsKeyId': '', 'S3OutputPath': 's3://zurich-aiml-projects/cardamagedetective/modeloutput'}, 'ResourceConfig': {'InstanceType': 'ml.p2.xlarge', 'InstanceCount': 1, 'VolumeSizeInGB': 50}, 'StoppingCondition': {'MaxRuntimeInSeconds': 360000}, 'CreationTime': datetime.datetime(2019, 6, 21, 11, 0, 4, 951000, tzinfo=tzlocal()), 'TrainingStartTime': datetime.datetime(2019, 6, 21, 11, 3, 28, 432000, tzinfo=tzlocal()), 'TrainingEndTime': datetime.datetime(2019, 6, 21, 11, 7, 2, 98000, tzinfo=tzlocal()), 'LastModifiedTime': datetime.datetime(2019, 6, 21, 11, 7, 2, 98000, tzinfo=tzlocal()), 'SecondaryStatusTransitions': [{'Status': 'Starting', 'StartTime': datetime.datetime(2019, 6, 21, 11, 0, 4, 951000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2019, 6, 21, 11, 3, 28, 432000, tzinfo=tzlocal()), 'StatusMessage': 'Preparing the instances for training'}, {'Status': 'Downloading', 'StartTime': datetime.datetime(2019, 6, 21, 11, 3, 28, 432000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2019, 6, 21, 11, 3, 56, 793000, tzinfo=tzlocal()), 'StatusMessage': 'Downloading input data'}, {'Status': 'Training', 'StartTime': datetime.datetime(2019, 6, 21, 11, 3, 56, 793000, tzinfo=tzlocal()), 'EndTime': datetime.datetime(2019, 6, 21, 11, 6, 25, 532000, tzinfo=tzlocal()), 'StatusMessage': 'Training image download completed. Training in progress.'}, {'Status': 'Uploading', 'Start ...

# %%
# %%time
#Create Model
import boto3
from time import gmtime, strftime

sage = boto3.Session().client(service_name='sagemaker') 
timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())

model_name="cardamagedetective-damage-location" + timestamp
print(model_name)

info = sage.describe_training_job(TrainingJobName=job_name)
model_data = info['ModelArtifacts']['S3ModelArtifacts']
print(model_data)

hosting_image = get_image_uri(boto3.Session().region_name, 'image-classification')
primary_container = {
    'Image': hosting_image,
    'ModelDataUrl': model_data,
}

create_model_response = sage.create_model(
    ModelName = model_name,
    ExecutionRoleArn = role,
    PrimaryContainer = primary_container)

print(create_model_response['ModelArn'])
# Out:
# cardamagedetective-damage-location-2019-06-21-11-08-16
# s3://zurich-aiml-projects/cardamagedetective/modeloutput/cardamagedetective-damage-severity-2019-06-21-10-59-27/output/model.tar.gz
# arn:aws:sagemaker:us-east-1:811843694063:model/cardamagedetective-damage-location-2019-06-21-11-08-16
# CPU times: user 66.8 ms, sys: 3.94 ms, total: 70.7 ms
# Wall time: 408 ms

# %%
#Create Endpoint Configuration for the model craeted/stored in S3
from time import gmtime, strftime

timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_config_name = job_name_prefix + '-epc-' + timestamp
endpoint_config_response = sage.create_endpoint_config(
    EndpointConfigName = endpoint_config_name,
    ProductionVariants=[{
        'InstanceType':'ml.m4.xlarge',
        'InitialInstanceCount':1,
        'ModelName':model_name,
        'VariantName':'AllTraffic'}])

print('Endpoint configuration name: {}'.format(endpoint_config_name))
print('Endpoint configuration arn:  {}'.format(endpoint_config_response['EndpointConfigArn']))
# Out:
# Endpoint configuration name: cardamagedetective-damage-severity-epc--2019-06-21-11-08-23
# Endpoint configuration arn:  arn:aws:sagemaker:us-east-1:811843694063:endpoint-config/cardamagedetective-damage-severity-epc--2019-06-21-11-08-23

# %%
# %%time
#Create Endpoint by leveraging abovementioned Endpoint Configuration so that this cam be consumed by the end client applications
import time

timestamp = time.strftime('-%Y-%m-%d-%H-%M-%S', time.gmtime())
endpoint_name = job_name_prefix + '-ep-' + timestamp
print('Endpoint name: {}'.format(endpoint_name))

endpoint_params = {
    'EndpointName': endpoint_name,
    'EndpointConfigName': endpoint_config_name,
}
endpoint_response = sagemaker.create_endpoint(**endpoint_params)
print('EndpointArn = {}'.format(endpoint_response['EndpointArn']))
# Out:
# Endpoint name: cardamagedetective-damage-severity-ep--2019-06-21-11-08-41
# EndpointArn = arn:aws:sagemaker:us-east-1:811843694063:endpoint/cardamagedetective-damage-severity-ep--2019-06-21-11-08-41
# CPU times: user 14.2 ms, sys: 175 µs, total: 14.3 ms
# Wall time: 239 ms

# %%
# Get the status of the endpoint
response = sagemaker.describe_endpoint(EndpointName=endpoint_name)
status = response['EndpointStatus']
print('EndpointStatus = {}'.format(status))


# wait until the status has changed
sagemaker.get_waiter('endpoint_in_service').wait(EndpointName=endpoint_name)


# print the status of the endpoint
endpoint_response = sagemaker.describe_endpoint(EndpointName=endpoint_name)
status = endpoint_response['EndpointStatus']
print('Endpoint creation ended with EndpointStatus = {}'.format(status))

if status != 'InService':
    raise Exception('Endpoint creation failed.')
# Out:
# EndpointStatus = Creating
# Endpoint creation ended with EndpointStatus = InService

# %%
#Perform Inference
import boto3
runtime = boto3.Session().client(service_name='runtime.sagemaker')

# %%
#Model testing with single image
#Download image
#Make corresponding S3 dataset folder public
#!wget -O /tmp/test.jpg https://s3.amazonaws.com/zurich-aiml-projects/cardamagedetective/dataset/data3a/training/01-minor/0001.JPEG
#!wget -O /tmp/test.jpg https://s3.amazonaws.com/zurich-aiml-projects/cardamagedetective/dataset/data3a/training/02-moderate/0002.JPEG
#!wget -O /tmp/test.jpg https://s3.amazonaws.com/zurich-aiml-projects/cardamagedetective/dataset/data3a/training/03-severe/0001.JPEG
# !wget -O /tmp/test.jpg https://upload.wikimedia.org/wikipedia/commons/4/46/Car_Accident.jpg
#!wget -O /tmp/test.jpg https://upload.wikimedia.org/wikipedia/commons/thumb/2/25/2015_Mazda_MX-5_ND_2.0_SKYACTIV-G_160_i-ELOOP_Rubinrot-Metallic_Vorderansicht.jpg/1920px-2015_Mazda_MX-5_ND_2.0_SKYACTIV-G_160_i-ELOOP_Rubinrot-Metallic_Vorderansicht.jpg
file_name = '/tmp/test.jpg'
# test image
from IPython.display import Image
Image(file_name)
# Out:
# --2019-06-21 11:20:08--  https://upload.wikimedia.org/wikipedia/commons/4/46/Car_Accident.jpg
# Resolving upload.wikimedia.org (upload.wikimedia.org)... 208.80.154.240, 2620:0:861:ed1a::2:b
# Connecting to upload.wikimedia.org (upload.wikimedia.org)|208.80.154.240|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1732369 (1.7M) [image/jpeg]
# Saving to: ‘/tmp/test.jpg’
#
# /tmp/test.jpg       100%[===================>]   1.65M  --.-KB/s    in 0.05s
#
# 2019-06-21 11:20:08 (30.3 MB/s) - ‘/tmp/test.jpg’ saved [1732369/1732369]

# %%
import json
import numpy as np

with open(file_name, 'rb') as f:
    payload = f.read()
    payload = bytearray(payload)
response = runtime.invoke_endpoint(EndpointName=endpoint_name, 
                                   ContentType='application/x-image', 
                                   Body=payload)
result = response['Body'].read()
# result will be in json format and convert it to ndarray
result = json.loads(result)
# the result will output the probabilities for all classes
# find the class with maximum probability and print the class index
index = np.argmax(result)
object_categories = ['Minor damage', 'Moderate damage', 'Severe damage']
print("Result: label - " + object_categories[index] + ", probability - " + str(result[index]))
#for an image with no damage, it shows one of these 3 categories with low probability; in case of damaged image, it shows correly with high probability
# Out:
# Result: label - Severe damage, probability - 0.9954130053520203

# %%
#Delete endpoint to avoid incurring compute instance charges
sage.delete_endpoint(EndpointName=endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '90a0bf55-16af-47ca-bd5e-b3a880fdc376',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '90a0bf55-16af-47ca-bd5e-b3a880fdc376',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Fri, 21 Jun 2019 11:20:18 GMT'},
#   'RetryAttempts': 0}}
